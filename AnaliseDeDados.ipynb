# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('AI_Student_Life_india.csv')

# %%
df.head()
# Out:
#    Student_ID  Age  Gender Education_Level       City AI_Tool_Used  \
# 0           1   15  Female         College  Hyderabad      Copilot
# 1           2   21  Female      University    Chennai      Copilot
# 2           3   22    Male      University  Bangalore       Gemini
# 3           4   22    Male         College  Hyderabad      ChatGPT
# 4           5   22    Male         College  Hyderabad       Gemini
#
#    Daily_Usage_Hours   Purpose Impact_on_Grades Satisfaction_Level
# 0                1.1  Learning   Slight Decline             Medium
# 1                1.7    Coding   Slight Decline               High
# 2                1.5  Learning         Improved                Low
# 3                3.8  Research         Improved                Low
# 4                5.2    Coding   Slight Decline                Low

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Student_ID          400 non-null    int64
#  1   Age                 400 non-null    int64
#  2   Gender              400 non-null    str
#  3   Education_Level     400 non-null    str
#  4   City                400 non-null    str
#  5   AI_Tool_Used        400 non-null    str
#  6   Daily_Usage_Hours   400 non-null    float64
#  7   Purpose             400 non-null    str
#  8   Impact_on_Grades    400 non-null    str
#  9   Satisfaction_Level  400 non-null    str
# dtypes: float64(1), int64(2), str(7)
# memory usage: 50.2 KB

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      205
# Female    195
# Name: count, dtype: int64

# %%
df["Education_Level"].value_counts()
# Out:
# Education_Level
# College       146
# School        136
# University    118
# Name: count, dtype: int64

# %%
df["City"].value_counts()
# Out:
# City
# Delhi         37
# Chennai       32
# Bangalore     32
# Jaipur        32
# Pune          30
# Kolkata       30
# Lucknow       29
# Multan        29
# Ahmedabad     28
# Hyderabad     27
# Mumbai        23
# Lahore        22
# Islamabad     18
# Faisalabad    17
# Karachi       14
# Name: count, dtype: int64

# %%
df["AI_Tool_Used"].value_counts()
# Out:
# AI_Tool_Used
# Gemini       129
# ChatGPT      124
# Copilot      108
# Grammarly     24
# Notion AI     15
# Name: count, dtype: int64

# %%
df["Purpose"].value_counts()
# Out:
# Purpose
# Coding      104
# Writing      96
# Learning     88
# Research     88
# Homework     24
# Name: count, dtype: int64

# %%
df["Impact_on_Grades"].value_counts()
# Out:
# Impact_on_Grades
# Improved          139
# No Change         131
# Slight Decline    130
# Name: count, dtype: int64

# %%
df["Satisfaction_Level"].value_counts()
# Out:
# Satisfaction_Level
# High      149
# Low       142
# Medium    109
# Name: count, dtype: int64

# %%
df["Student_ID"].max()
# Out:
# np.int64(300)

# %%
df.loc[299:399, "Student_ID"]
# Out:
# 299    300
# 300      1
# 301      2
# 302      3
# 303      4
#       ...
# 395     96
# 396     97
# 397     98
# 398     99
# 399    100
# Name: Student_ID, Length: 101, dtype: int64

# %%
df["Student_ID"].value_counts()
# Out:
# Student_ID
# 1      2
# 2      2
# 3      2
# 4      2
# 5      2
#       ..
# 296    1
# 297    1
# 298    1
# 299    1
# 300    1
# Name: count, Length: 300, dtype: int64

# %%
df["Age"].max()
# Out:
# np.int64(25)

# %%
df["Age"].min()
# Out:
# np.int64(15)

# %%
df["Daily_Usage_Hours"].max()
# Out:
# np.float64(6.0)

# %%
df["Daily_Usage_Hours"].min()
# Out:
# np.float64(0.5)

# %% [markdown]
# **Há um erro no id dos alunos, onde, ao chegar no id 300, os próximos ids voltam a serem contados a partir do número 1**

# %%
filtroID = df.index >= 300
df.loc[filtroID, "Student_ID"] = df.loc[filtroID, "Student_ID"] + 300

# %%
df["Student_ID"].max()
# Out:
# np.int64(400)

# %%
plt.subplots(figsize=(5, 3))
sns.countplot(x="Age", data=df)
plt.xlabel("Age")
plt.show()

# %%
plt.subplots(figsize=(5, 3))
sns.countplot(x="Gender", data=df)
plt.xlabel("Gender")
plt.show()

# %%
plt.subplots(figsize=(5, 3))
sns.countplot(x="Education_Level", data=df)
plt.xlabel("Education_Level")
plt.show()

# %%
plt.subplots(figsize=(5, 3))
sns.countplot(x="City", data=df)
plt.xlabel("City")
plt.xticks(rotation=60)
plt.show()

# %%
plt.subplots(figsize=(5, 3))
sns.countplot(x="AI_Tool_Used", data=df)
plt.xlabel("AI_Tool_Used")
plt.show()

# %%
plt.subplots(figsize=(5, 3))
sns.boxplot(x="Daily_Usage_Hours", data=df)
plt.xlabel("Daily_Usage_Hours")
plt.show()

# %%
plt.subplots(figsize=(5, 3))
sns.countplot(x="Purpose", data=df)
plt.xlabel("Purpose")
plt.show()

# %%
plt.subplots(figsize=(5, 3))
sns.countplot(x="Impact_on_Grades", data=df)
plt.xlabel("Impact_on_Grades")
plt.show()

# %%
plt.subplots(figsize=(5, 3))
sns.countplot(x="Satisfaction_Level", data=df)
plt.xlabel("Satisfaction_Level")
plt.show()

# %%
plt.subplots(figsize=(15, 3))
sns.countplot(data=df, x="Age", hue="AI_Tool_Used")
plt.xlabel("Age")
plt.show()

# %%
plt.subplots(figsize=(15, 3))
sns.countplot(data=df, x="Gender", hue="AI_Tool_Used")
plt.xlabel("Gender")
plt.show()

# %%
plt.subplots(figsize=(15, 3))
sns.countplot(data=df, x="Education_Level", hue="AI_Tool_Used")
plt.xlabel("Education_Level")
plt.show()

# %%
plt.subplots(figsize=(15, 3))
sns.countplot(data=df, x="City", hue="AI_Tool_Used")
plt.xlabel("City")
plt.show()

# %%
plt.subplots(figsize=(10, 4))
sns.boxplot(data=df, x="Daily_Usage_Hours", hue="AI_Tool_Used")
plt.xlabel("Daily_Usage_Hours")
plt.show()

# %%
plt.subplots(figsize=(10, 4))
sns.countplot(data=df, x="Purpose", hue="AI_Tool_Used")
plt.xlabel("Purpose")
plt.show()

# %%
plt.subplots(figsize=(10, 4))
sns.countplot(data=df, x="Impact_on_Grades", hue="AI_Tool_Used")
plt.xlabel("Impact_on_Grades")
plt.show()

# %%
plt.subplots(figsize=(10, 4))
sns.countplot(data=df, x="Satisfaction_Level", hue="AI_Tool_Used")
plt.xlabel("Satisfaction_Level")
plt.show()
